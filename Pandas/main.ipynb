# %%
import pandas as pd

# %%
info = {
    "Name": ["Rahul","Hardik","Shraddha"],
    "CGPA": [9.5,10.5,8.5]
    
}
# Dataframes
df = pd.DataFrame(info) 
print(df)
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1    Hardik  10.5
# 2  Shraddha   8.5

# %%
s = pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s = pd.Series([23,24,25,26],index = ["Adam","Eve","Bob","Charlie"])
print(s)

print(s["Bob"])
# Out:
# Adam       23
# Eve        24
# Bob        25
# Charlie    26
# dtype: int64
# 25

# %%
s1 = pd.Series([1,2,3,4,5])

print(s1)
s1[0] = 100
print(s1)
s2 = s1.drop(0)
print(s2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 0    100
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: int64
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# Index(['Name', 'CGPA'], dtype='object')

# %%
d = pd.DataFrame([["Adam",200],["Eve",90],["Satan",100]],columns=["Name","Marks"])
print(d)
# Out:
#     Name  Marks
# 0   Adam    200
# 1    Eve     90
# 2  Satan    100
