# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = np.random.normal(70,10,1000)
plt.hist(data,color = "green",edgecolor = "black",bins = 20)
# Out:
# (array([  5.,   6.,   8.,  16.,  34.,  38.,  71.,  72., 100., 107., 104.,
#          96.,  89.,  86.,  63.,  50.,  29.,  13.,   6.,   7.]),
#  array([41.33821624, 44.11219841, 46.88618059, 49.66016276, 52.43414494,
#         55.20812711, 57.98210929, 60.75609146, 63.53007364, 66.30405581,
#         69.07803798, 71.85202016, 74.62600233, 77.39998451, 80.17396668,
#         82.94794886, 85.72193103, 88.49591321, 91.26989538, 94.04387756,
#         96.81785973]),
#  <BarContainer object of 20 artists>)

# %%
bins = [i for i in range(40,110,10)]
plt.hist(data,bins=bins,edgecolor="black")
# Out:
# (array([ 20., 138., 336., 333., 155.,  18.]),
#  array([ 40.,  50.,  60.,  70.,  80.,  90., 100.]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# # Calculation of bin:
#
# ## Total range: max-min
#
# ## Divide into equal parts: (max-min)/number of bins

# %%
legit_transactions = [
    2.99, 5.49, 8.99, 12.50, 14.99, 19.99, 23.45, 29.99, 34.99, 39.50,
    45.00, 49.99, 55.25, 60.00, 75.99, 89.99, 120.50, 150.00, 199.99,
    249.99, 300.75, 450.00, 600.00, 850.00, 1200.00
]

fraud_transactions = [
    50, 100, 150, 200, 300, 500, 500, 750, 1000, 1000,
    1200, 1500, 1500, 2000, 2500, 3000, 3000
]

plt.hist(legit_transactions,color="blue",bins = 10,label="Legit",edgecolor='black',alpha = 0.5)
plt.hist(fraud_transactions,color="red",bins = 10,label="Fraud",alpha = 0.5,edgecolor='black')
# Out:
# (array([5., 2., 1., 3., 2., 0., 1., 0., 1., 2.]),
#  array([  50.,  345.,  640.,  935., 1230., 1525., 1820., 2115., 2410.,
#         2705., 3000.]),
#  <BarContainer object of 10 artists>)

# %%
data = [7,8,1,3,4,5,6,10,25,18,42]
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24f4ffc7770>,
#   <matplotlib.lines.Line2D at 0x24f4ffc79e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x24f4ffc7cb0>,
#   <matplotlib.lines.Line2D at 0x24f4ffc7f50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24f4ffc7530>],
#  'medians': [<matplotlib.lines.Line2D at 0x24f4fffc200>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24f4fffc500>],
#  'means': []}
