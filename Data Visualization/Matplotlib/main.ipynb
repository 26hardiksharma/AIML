# %%
import matplotlib.pyplot as plt

# %%
X = [1,2,3,4]
Y = [5,6,7,8]

plt.plot(X,Y)

# %%
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]

years = [2008,2009,2010,2011,2012]
revenue = [1005,170,427,133,232]

# %%
# plt.plot(years,revenue)
# plt.title("Movies ")
# plt.xlabel("Year")
# plt.ylabel("Revenue")

# %%
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378,2788,829,185,275]

plt.plot(years,revenue,label = "Oscar Movies")
plt.plot(years,non_oscar_revenue,label = "Non oscar movies")
plt.title("Oscar Movies VS Non oscar movies")
plt.legend()
plt.style.available
plt.style.use("dark_background")

# %%
plt.bar(years,revenue)
plt.bar(years,non_oscar_revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(oscar_movies,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.scatter(years,revenue)
plt.scatter(years,non_oscar_revenue)

# %%
expenses = ["R&D","Management","Salaries","Rent","Marketing"]
amt = [100,200,100,1000,800]

plt.pie(amt,labels = expenses)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f4721c9a30>,
# ...
#  [Text(1.0888035854028022, 0.15654632673430227, 'R&D'),
#   Text(0.9253788759906099, 0.5947049149539254, 'Management'),
#   Text(0.5947048716338131, 0.9253789038307552, 'Salaries'),
#   Text(-0.9253789316708985, 0.5947048283136995, 'Rent'),
#   Text(0.45695666760067855, -1.0005951248808298, 'Marketing')])
